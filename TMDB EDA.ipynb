# %% [markdown]
# # TMDB EDA
# Name: Michael McCann
# Last Updetd: 30 APR 2022

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %% [markdown]
# ## Load and Inspect Data

# %%
tmdb_2k = pd.read_csv('data/final_tmdb_data_2000.csv.gz')
tmdb_2k1 = pd.read_csv('data/final_tmdb_data_2001.csv.gz')

# %%
display(tmdb_2k.head())
print('\n\n')
tmdb_2k.info()
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg                   NaN
# 2  tt0113092    0.0                               NaN                   NaN
# 3  tt0116391    0.0                               NaN                   NaN
# 4  tt0118694    0.0  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg                   NaN
#
#        budget                                             genres  \
# 0         NaN                                                NaN
# 1  10000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...
# 2         0.0           [{'id': 878, 'name': 'Science Fiction'}]
# 3         0.0  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# 4    150000.0  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
#
#                                homepage        id original_language  \
# 0                                   NaN       NaN               NaN
# 1                                   NaN   62127.0                en
# 2                                   NaN  110977.0                en
# 3                                   NaN  442869.0                hi
# 4  http://www.wkw-inthemoodforlove.com/     843.0                cn
#
#     original_title  ...     revenue  runtime  \
# 0              NaN  ...         NaN      NaN
# 1  The Fantasticks  ...         0.0     86.0
# 2    For the Cause  ...         0.0    100.0
# 3             Gang  ...         0.0    152.0
# 4             花樣年華  ...  12854953.0     99.0
#
#                                     spoken_languages    status  \
# 0                                                NaN       NaN
# 1  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 3  [{'english_name': 'Hindi', 'iso_639_1': 'hi', ...  Released
# 4  [{'english_name': 'Cantonese', 'iso_639_1': 'c...  Released
#
#                                              tagline                 title  \
# 0                                                NaN                   NaN
# 1      Try to remember the first time magic happened       The Fantasticks
# 2       The ultimate showdown on a forbidden planet.         For the Cause
# 3                                                NaN                  Gang
# 4  Feel the heat, keep the feeling burning, let t...  In the Mood for Love
#
#    video  vote_average vote_count certification
# 0    NaN           NaN        NaN           NaN
# 1    0.0           5.4       21.0           NaN
# 2    0.0           4.4        7.0           NaN
# 3    0.0           0.0        0.0           NaN
# 4    0.0           8.1     1860.0            PG
#
# [5 rows x 26 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1197 entries, 0 to 1196
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_id                1197 non-null   object
#  1   adult                  1196 non-null   float64
#  2   backdrop_path          608 non-null    object
#  3   belongs_to_collection  107 non-null    object
#  4   budget                 1196 non-null   float64
#  5   genres                 1196 non-null   object
#  6   homepage               65 non-null     object
#  7   id                     1196 non-null   float64
#  8   original_language      1196 non-null   object
#  9   original_title         1196 non-null   object
#  10  overview               1172 non-null   object
#  11  popularity             1196 non-null   float64
#  12  poster_path            1051 non-null   object
#  13  production_companies   1196 non-null   object
#  14  production_countries   1196 non-null   object
#  15  release_date           1184 non-null   object
#  16  revenue                1196 non-null   float64
#  17  runtime                1178 non-null   float64
#  18  spoken_languages       1196 non-null   object
#  19  status                 1196 non-null   object
#  20  tagline                501 non-null    object
#  21  title                  1196 non-null   object
#  22  video                  1196 non-null   float64
#  23  vote_average           1196 non-null   float64
#  24  vote_count             1196 non-null   float64
#  25  certification          370 non-null    object
# dtypes: float64(9), object(17)
# memory usage: 243.3+ KB

# %%
display(tmdb_2k1.head())
print('\n\n')
tmdb_2k1.info()
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt0035423    0.0  /hfeiSfWYujh6MKhtGTXyK3DD4nN.jpg                   NaN
# 2  tt0114447    0.0                               NaN                   NaN
# 3  tt0118589    0.0  /bLntSfsqUheiUirdV9Ts8znqsTM.jpg                   NaN
# 4  tt0118652    0.0  /mWxJEFRMvkG4UItYJkRDMgWQ08Y.jpg                   NaN
#
#        budget                                             genres homepage  \
# 0         NaN                                                NaN      NaN
# 1  48000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 14, 'nam...      NaN
# 2         0.0  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...      NaN
# 3  22000000.0  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...      NaN
# 4   1000000.0  [{'id': 9648, 'name': 'Mystery'}, {'id': 27, '...      NaN
#
#          id original_language         original_title  ...     revenue  \
# 0       NaN               NaN                    NaN  ...         NaN
# 1   11232.0                en         Kate & Leopold  ...  76019048.0
# 2  151007.0                en       The Silent Force  ...         0.0
# 3   10696.0                en                Glitter  ...   5271666.0
# 4   17140.0                en  The Attic Expeditions  ...         0.0
#
#    runtime                                   spoken_languages    status  \
# 0      NaN                                                NaN       NaN
# 1    118.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2     90.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 3    104.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 4    100.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                                              tagline                  title  \
# 0                                                NaN                    NaN
# 1  If they lived in the same century they'd be pe...         Kate & Leopold
# 2  They left him for dead... They should have fin...       The Silent Force
# 3   In music she found her dream, her love, herself.                Glitter
# 4  His search for peace of mind... will leave his...  The Attic Expeditions
#
#    video  vote_average vote_count certification
# 0    NaN           NaN        NaN           NaN
# 1    0.0           6.3     1103.0         PG-13
# 2    0.0           5.0        3.0           NaN
# 3    0.0           4.6      115.0         PG-13
# 4    0.0           5.0       27.0             R
#
# [5 rows x 26 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1277 entries, 0 to 1276
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_id                1277 non-null   object
#  1   adult                  1276 non-null   float64
#  2   backdrop_path          631 non-null    object
#  3   belongs_to_collection  85 non-null     object
#  4   budget                 1276 non-null   float64
#  5   genres                 1276 non-null   object
#  6   homepage               106 non-null    object
#  7   id                     1276 non-null   float64
#  8   original_language      1276 non-null   object
#  9   original_title         1276 non-null   object
#  10  overview               1247 non-null   object
#  11  popularity             1276 non-null   float64
#  12  poster_path            1106 non-null   object
#  13  production_companies   1276 non-null   object
#  14  production_countries   1276 non-null   object
#  15  release_date           1266 non-null   object
#  16  revenue                1276 non-null   float64
#  17  runtime                1248 non-null   float64
#  18  spoken_languages       1276 non-null   object
#  19  status                 1276 non-null   object
#  20  tagline                518 non-null    object
#  21  title                  1276 non-null   object
#  22  video                  1276 non-null   float64
#  23  vote_average           1276 non-null   float64
#  24  vote_count             1276 non-null   float64
#  25  certification          415 non-null    object
# dtypes: float64(9), object(17)
# memory usage: 259.5+ KB

# %% [markdown]
# ## Merge DataFrames

# %%
tmdb_merged = pd.concat([tmdb_2k, tmdb_2k1], ignore_index = True)
tmdb_merged
# Out:
#         imdb_id  adult                     backdrop_path  \
# 0             0    NaN                               NaN
# 1     tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg
# 2     tt0113092    0.0                               NaN
# 3     tt0116391    0.0                               NaN
# 4     tt0118694    0.0  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg
# ...         ...    ...                               ...
# 2469  tt7797670    0.0                               NaN
# 2470  tt7797790    0.0                               NaN
# 2471  tt8665056    0.0                               NaN
# 2472  tt8795764    0.0                               NaN
# 2473  tt9071078    0.0                               NaN
#
#      belongs_to_collection      budget  \
# 0                      NaN         NaN
# 1                      NaN  10000000.0
# 2                      NaN         0.0
# 3                      NaN         0.0
# 4                      NaN    150000.0
# ...                    ...         ...
# 2469                   NaN         0.0
# 2470                   NaN         0.0
# 2471                   NaN         0.0
# 2472                   NaN         0.0
# 2473                   NaN         0.0
#
#                                                  genres  \
# 0                                                   NaN
# 1     [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...
# 2              [{'id': 878, 'name': 'Science Fiction'}]
# 3     [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# 4     [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# ...                                                 ...
# 2469                     [{'id': 27, 'name': 'Horror'}]
# 2470                     [{'id': 27, 'name': 'Horror'}]
# 2471                    [{'id': 37, 'name': 'Western'}]
# 2472                     [{'id': 27, 'name': 'Horror'}]
# 2473                     [{'id': 28, 'name': 'Action'}]
#
#                                                homepage        id  \
# 0                                                   NaN       NaN
# 1                                                   NaN   62127.0
# 2                                                   NaN  110977.0
# 3                                                   NaN  442869.0
# 4                  http://www.wkw-inthemoodforlove.com/     843.0
# ...                                                 ...       ...
# 2469                                                NaN  956214.0
# 2470                                                NaN  956219.0
# 2471  http://skeletoncreekproductions.com/p-movie-br...  885436.0
# 2472  https://www.utahwolf.com/films/coming-soon-new...  871624.0
# 2473    http://www.hkcinemagic.com/en/movie.asp?id=6627  201706.0
#
#      original_language                              original_title  ...  \
# 0                  NaN                                         NaN  ...
# 1                   en                             The Fantasticks  ...
# 2                   en                               For the Cause  ...
# 3                   hi                                        Gang  ...
# 4                   cn                                        花樣年華  ...
# ...                ...                                         ...  ...
# 2469                en  Edmund Kemper Part 2: La Mort C'est La Vie  ...
# 2470                en         Edmund Kemper Part 3: La mort sévit  ...
# 2471                en                        Guns Along The Bravo  ...
# 2472                en                                   New Breed  ...
# 2473                cn                                        致命密函  ...
#
#          revenue  runtime                                   spoken_languages  \
# 0            NaN      NaN                                                NaN
# 1            0.0     86.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 2            0.0    100.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 3            0.0    152.0  [{'english_name': 'Hindi', 'iso_639_1': 'hi', ...
# 4     12854953.0     99.0  [{'english_name': 'Cantonese', 'iso_639_1': 'c...
# ...          ...      ...                                                ...
# 2469         0.0     91.0                                                 []
# 2470         0.0     72.0  [{'english_name': 'French', 'iso_639_1': 'fr',...
# 2471         0.0     85.0                                                 []
# 2472         0.0     57.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 2473         0.0     90.0  [{'english_name': 'Cantonese', 'iso_639_1': 'c...
#
#         status                                            tagline  \
# 0          NaN                                                NaN
# 1     Released      Try to remember the first time magic happened
# 2     Released       The ultimate showdown on a forbidden planet.
# 3     Released                                                NaN
# 4     Released  Feel the heat, keep the feeling burning, let t...
# ...        ...                                                ...
# 2469  Released                                                NaN
# 2470  Released                                                NaN
# 2471  Released  Evil came to the Southwest until three blazing...
# 2472  Released                                                NaN
# 2473  Released                                                NaN
#
#                                            title  video  vote_average  \
# 0                                            NaN    NaN           NaN
# 1                                The Fantasticks    0.0           5.4
# 2                                  For the Cause    0.0           4.4
# 3                                           Gang    0.0           0.0
# 4                           In the Mood for Love    0.0           8.1
# ...                                          ...    ...           ...
# 2469  Edmund Kemper Part 2: La Mort C'est La Vie    0.0           0.0
# 2470         Edmund Kemper Part 3: La mort sévit    0.0           0.0
# 2471                        Guns Along The Bravo    0.0           0.0
# 2472                                   New Breed    0.0           0.0
# 2473                              Chinese Heroes    0.0           3.0
#
#      vote_count certification
# 0           NaN           NaN
# 1          21.0           NaN
# 2           7.0           NaN
# 3           0.0           NaN
# 4        1860.0            PG
# ...         ...           ...
# 2469        0.0           NaN
# 2470        0.0           NaN
# 2471        0.0           NaN
# 2472        0.0            NR
# 2473        2.0           NaN
#
# [2474 rows x 26 columns]

# %% [markdown]
# ## EDA

# %%
budget = tmdb_merged['budget'] > 0
revenue = tmdb_merged['revenue'] > 0

print(f'Only {budget.sum()} database entries for 2000/2001 have budget information.')
print(f'Only {revenue.sum()} database entries for 2000/2001 have revenue information.')
# Out:
# Only 536 database entries for 2000/2001 have budget information.
# Only 425 database entries for 2000/2001 have revenue information.

# %%
tmdb_fin = tmdb_merged[budget & revenue]

# %%
tmdb_fin.groupby('certification')['id'].count().sort_values(ascending = False)
# Out:
# certification
# R        138
# PG-13    117
# PG        29
# G         13
# NR         6
# Name: id, dtype: int64

# %% [markdown]
# ### Viz: Distriubution by Rating

# %%
## Set certification to a categorical ordering
tmdb_fin['certification'] = pd.Categorical(tmdb_fin['certification'],
                                           ['R','PG-13','PG','G', 'NR'])
## Visualize Distribution by Rating
fig, ax = plt.subplots(figsize = (10,5))
sns.histplot(y = tmdb_fin['certification'], 
             color = "#006400", alpha = .8, shrink = .85)
plt.title('Movie by Rating\n 2000 and 2001', 
             fontsize = 18, weight = 'bold')
plt.xlabel('Revenue', fontsize=14, weight = 'semibold')
plt.ylabel('Rating',  fontsize=14, weight = 'semibold')
plt.grid(axis = 'x', alpha = .6)
ax.set_axisbelow(True)
fig.tight_layout()
# Out:
# G:\Program Files (x86)\anaconda3\envs\dojo-env\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# ### Viz: Mean Budget and Revenue by Rating

# %%
tmdb_fin.groupby('certification')['budget'].mean().sort_values(ascending = False)
# Out:
# certification
# PG       5.374138e+07
# PG-13    4.680682e+07
# G        4.400000e+07
# R        2.762578e+07
# NR       1.478333e+07
# Name: budget, dtype: float64

# %%
tmdb_fin.groupby('certification')['revenue'].mean().sort_values(ascending = False)
# Out:
# certification
# G        1.332169e+08
# PG       1.332132e+08
# PG-13    1.105770e+08
# R        5.392480e+07
# NR       2.382332e+07
# Name: revenue, dtype: float64

# %%
from matplotlib.ticker import StrMethodFormatter

fig, axes = plt.subplots(figsize=(10,8), nrows = 2, sharex = True)
plt.suptitle('Movie Budget and Revenue by Rating\n 2000 and 2001', 
             fontsize = 18, weight = 'bold', y = 1.06)
sns.barplot(data = tmdb_fin, x = 'budget', y = 'certification', 
            ci = None, color = "red", alpha = .8, ax = axes[0])
axes[0].set_xlabel('Budget', fontsize=14, weight = 'semibold')
axes[0].set_ylabel('Rating',  fontsize=14, weight = 'semibold')
sns.barplot(data = tmdb_fin, x = 'revenue', y = 'certification', 
            ci = None, color = "#006400", alpha = .8, ax = axes[1])
axes[1].set_xlabel('Revenue', fontsize=14, weight = 'semibold')
axes[1].set_ylabel('Rating',  fontsize=14, weight = 'semibold')
[ax.grid(axis = 'x', alpha = .6) for ax in axes]
[ax.set_axisbelow(True) for ax in axes]
axes[1].xaxis.set_major_formatter(StrMethodFormatter('${x:,.0f}'))
plt.xlim(0,140000000)
plt.xticks(range(0, 141000000, 10000000),rotation = 30, ha = 'right')
fig.tight_layout()

# %% [markdown]
# ### Viz: Relationship between Budget and Revenue

# %%
fig, ax = plt.subplots(figsize = (10,10))
sns.scatterplot(data = tmdb_fin, x = 'budget', y = 'revenue', hue = "certification", alpha = .8);
sns.regplot(data=tmdb_fin[tmdb_fin['certification'] == 'R'], x = 'budget', y = 'revenue', 
            scatter_kws={'s':0}, ci=None,
            line_kws={'color': '#1e81b0', 'lw' : 2, 'alpha' : .8})
sns.regplot(data=tmdb_fin[tmdb_fin['certification'] == 'PG-13'], x = 'budget', y = 'revenue', 
            scatter_kws={'s':0}, ci=None,
            line_kws={'color': "orange", 'lw' : 2, 'alpha' : .8})
sns.regplot(data=tmdb_fin[tmdb_fin['certification'] == 'PG'], x = 'budget', y = 'revenue', 
            scatter_kws={'s':0}, ci=None,
            line_kws={'color': "green", 'lw' : 2, 'alpha' : .7})
sns.regplot(data=tmdb_fin[tmdb_fin['certification'] == 'G'], x = 'budget', y = 'revenue', 
            scatter_kws={'s':0}, ci=None,
            line_kws={'color': "red", 'lw' : 2, 'alpha' : .7})
sns.regplot(data=tmdb_fin[tmdb_fin['certification'] == 'NR'], x = 'budget', y = 'revenue', 
            scatter_kws={'s':0}, ci=None,
            line_kws={'color': "purple", 'lw' : 2, 'alpha' : .7})
plt.title('Relationship between Budget and Revenue\n 2000 and 2001', 
             fontsize = 18, weight = 'bold')
plt.xlabel('Budget', fontsize=14, weight = 'semibold')
plt.ylabel('Revenue',  fontsize=14, weight = 'semibold')
ax.xaxis.set_major_formatter(StrMethodFormatter('${x:,.0f}'))
ax.yaxis.set_major_formatter(StrMethodFormatter('${x:,.0f}'))
plt.xlim(0,140000000)
plt.ylim(0,600000000)
plt.grid(alpha = .5)
plt.xticks(rotation = 30, ha = 'right')
fig.tight_layout()
